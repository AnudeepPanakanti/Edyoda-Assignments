# %%
import pandas as pd

# Step 1: Import the dataset and assign it to a variable called 'users' with 'user_id' as the index
users = pd.read_csv('RawData.csv', index_col='user_id')

# Step 2: See the first 10 and last 10 entries
print(users.head(10))
print(users.tail(10))

# Step 3: What is the number of observations in the dataset?
num_observations = len(users)
print("Number of observations:", num_observations)

# Step 4: What is the number of columns in the dataset?
num_columns = len(users.columns)
print("Number of columns:", num_columns)

# Step 5: Print the name of all the columns.
print("Column names:", list(users.columns))

# Step 6: How is the dataset indexed?
print("Index type:", users.index)

# Step 7: What is the data type of each column?
print("Data types of each column:")
print(users.dtypes)

# Step 8: Print only the occupation column
print("Occupation column:")
print(users['occupation'])

# Step 9: How many different occupations are in this dataset?
num_occupations = users['occupation'].nunique()
print("Number of different occupations:", num_occupations)

# Step 10: What is the most frequent occupation?
most_frequent_occupation = users['occupation'].value_counts().idxmax()
print("Most frequent occupation:", most_frequent_occupation)

# Step 11: Data Frame Info.
print("Data Frame Info:")
print(users.info())

# Step 12: Describe all the columns
print("Description of all columns:")
print(users.describe())

# Step 13: Summarize only the occupation column
print("Summary of the occupation column:")
print(users['occupation'].describe())

# Step 14: What is the mean age of users?
mean_age = users['age'].mean()
print("Mean age of users:", mean_age)

# Step 15: What is the age with the least occurrence?
age_with_least_occurrence = users['age'].value_counts().idxmin()
print("Age with least occurrence:", age_with_least_occurrence)
